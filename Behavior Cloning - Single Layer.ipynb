# %%
import csv
import cv2
import numpy as np

lines=[]

with open('data/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)

# %%
images = []
measurements = []
# for line in lines:
#     source_path = line[0]
#     filename = source_path.split('/')[-1]
#     current_path = './data/IMG/' + filename
#     image = cv2.imread(current_path)
#     images.append(image)
    
#     measurement = float(line[3])
#     measurements.append(measurement)

# %%
import pandas as pd
log_pd = pd.read_csv('data/driving_log.csv')

# %%
measurements = log_pd['steering']
image_fname = log_pd['center']

# %%
print(measurements.shape)
print(image_fname.shape)
print(measurements[0:2])
print(image_fname[0:2])
print(type(measurements))
print(type(image_fname))
measurements=np.array(measurements)
print(type(measurements))
# Out:
# (8036,)
# (8036,)
# [ 0.  0.]
# 0    IMG/center_2016_12_01_13_30_48_287.jpg
# 1    IMG/center_2016_12_01_13_30_48_404.jpg
# Name: center, dtype: object
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
# X_train = np.array(images)
y_train = np.array(measurements)
images = []
for img in image_fname:
    image = cv2.imread('data/' + img)
    images.append(image)
X_train = np.array(images)

print(X_train.shape)
# Out:
# (8036, 160, 320, 3)

# %%
# Out:
# [array([[[208, 163, 130],
#          [208, 163, 130],
#          [208, 163, 130],
#          ...,
#          [210, 163, 131],
#          [210, 163, 131],
#          [210, 163, 131]],
#
#         [[208, 163, 130],
#          [208, 163, 130],
#          [208, 163, 130],
#          ...,
#          [210, 163, 131],
#          [210, 163, 131],
#          [210, 163, 131]],
#
#         [[209, 164, 131],
#          [209, 164, 131],
#          [209, 164, 131],
#          ...,
#          [211, 164, 132],
#          [211, 164, 132],
#          [211, 164, 132]],
#
#         ...,
#         [[ 83,  99, 112],
#          [ 88, 104, 117],
#          [ 89, 106, 119],
#          ...,
#          [ 99, 116, 135],
#          [106, 123, 142],
#          [111, 128, 147]],
#
#         [[ 92, 109, 122],
#          [ 88, 105, 118],
#          [ 82,  99, 112],
#          ...,
#          [104, 123, 144],
#          [ 96, 115, 136],
#          [ 91, 110, 131]],
#
#         [[ 87, 104, 117],
#          [ 79,  96, 109],
#          [ 79,  95, 111],
#          ...,
#          [115, 134, 155],
#          [106, 125, 146],
#          [ 99, 118, 139]]], dtype=uint8)]

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense

model = Sequential()
model.add(Flatten(input_shape=(160,320,3)))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

model.fit(X_train,y_train, validation_split=0.2,shuffle=True, nb_epoch=5)

model.save('model.h5')
# Out:
# Train on 6428 samples, validate on 1608 samples
# Epoch 1/5
#  - ETA: 2s - loss: 15255153.4203
# Epoch 2/5
#  - ETA: 0s - loss: 3344.7967
# Epoch 3/5
# 6428/6428 [==============================] - 4s - loss: 2309.4281 - val_loss: 1839.3139
# Epoch 4/5
#  - ETA: 3s - loss: 2236.4435
